# %%
from sqlalchemy import create_engine, text

# %%
# engine = create_engine("mysql://root:123@host.docker.internal:3306/oracle")
engine = create_engine('mysql://root:123@127.0.0.1:3307/oracle')

# %%
with engine.connect() as conn:
    stmt = text('select 1')
    result = conn.execute(stmt)
    print(result.fetchall())
# Out:
# [(1,)]

# %%
from sqlalchemy import Column, Integer, String, DateTime, Boolean
from sqlalchemy.orm import declarative_base
from datetime import datetime

Base = declarative_base()

class UserActivity(Base):
    __tablename__ = 'user_activity'
    
    id = Column(Integer, primary_key=True)
    username = Column(String(50), nullable=False)
    activity_type = Column(String(100))
    location = Column(String(80))
    timestamp = Column(DateTime, default=datetime.now)
    
    def __repr__(self):
        return f"<UserActivity(id={self.id}, user='{self.username}')>"

# 테이블 생성
Base.metadata.create_all(bind=engine)

# %%
from sqlalchemy.orm import Session

with Session(engine) as session:
    # CREATE
    activity = UserActivity(username="alice", activity_type="login", location="Seoul")
    session.add(activity)
    session.commit()

# %% [markdown]
# - s_name
# - gugun_name
# - defaultimage
# - addr
# - lat
# - lot

# %%
from sqlalchemy import Float

Base2 = declarative_base()

class Starbucks(Base2):
    __tablename__ = 'starbucks'
    
    s_name = Column(String(200), primary_key=True)
    gugun_name = Column(String(100))
    #defaultimage
    default_image = Column(String(300))
    addr = Column(String(80))
    lat = Column(Float())
    lot = Column(Float())

    def __repr__(self):
        return

# 테이블 생성
Base2.metadata.create_all(bind=engine)

# %%
import requests

payload = {"in_biz_cds":"0",
"in_scodes":"0",
"ins_lat":"37.56682",
"ins_lng":"126.97865",
"search_text":"",
"p_sido_cd":"01",
"p_gugun_cd":"",
"in_distance":"0",
"in_biz_cd":"",
"isError":"true",
"searchType":"C",
"set_date":"",
"all_store":"0",
"T03":"0",
"T01":"0",
"T27":"0",
"T12":"0",
"T09":"0",
"T30":"0",
"T05":"0",
"T22":"0",
"T21":"0",
"T36":"0",
"T43":"0",
"Z9999":"0",
"T64":"0",
"P02":"0",
"P10":"0",
"P50":"0",
"P20":"0",
"P60":"0",
"P30":"0",
"P70":"0",
"P40":"0",
"P80":"0",
"whcroad_yn":"0",
"P90":"0",
"P01":"0",
"new_bool":"0",
"iend":"1000",
"rndCod":"ZI20ETDAT8",}

starbucks = "https://www.starbucks.co.kr/store/getStore.do?r=4RVFP1RE84"

starbucks_address = requests.post(starbucks, data=payload).json()

# %%
starbucks_address['list'][0]['defaultimage']

# %%
starbucks_list = []

for data in starbucks_address['list']:
    starbucks_list.append(Starbucks(s_name=data['s_name'],
                  gugun_name=data['gugun_name'],
                   default_image=data['defaultimage'],
                   addr = data['addr'],
                    lat=  data['lat'], lot= data['lot']))



starbucks_list2 = [Starbucks(s_name = data['s_name'],
                  gugun_name= data['gugun_name'],
                   default_image=  data['defaultimage'],
                   addr = data['addr'],
                    lat=  data['lat'], lot= data['lot']) for data in starbucks_address['list'] ]

# %%
from sqlalchemy.orm import Session

with Session(engine) as session:
    #CREATE
    session.add_all(starbucks_list2)
    session.commit()

# %%
import pandas as pd

# %%
df = pd.read_sql_query('select * from starbucks', con=engine)

# %%
df.columns

# %%
# 예외처리
try:
    1 / 0
except ZeroDivisionError:
    print('0으로 나누지마')
except Exception as e:
    print(e)

# %%
import certifi
print(certifi.where())

# %%
import os
import ssl
from urllib.request import urlretrieve

ssl._create_default_https_context = ssl._create_unverified_context

os.makedirs('./starbucks', exist_ok=True)
url = "https://www.starbucks.co.kr" + df['default_image'][0]

urlretrieve(url, './starbucks/a.jpg')
# Out:
# ('./starbucks/a.jpg', <http.client.HTTPMessage at 0x111e9d250>)

# %%
from tqdm import tqdm

for idx, url in tqdm(df[['s_name', 'default_image']].iterrows()):
    # print(url['default_image'], url['s_name'])
    full_url = "https://www.starbucks.co.kr"  + url['default_image']
    urlretrieve(full_url, f'./starbucks/{url['s_name']}.jpg')
# Out:
# 501it [02:46,  3.01it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 6
#       2
#       3 for idx, url in tqdm(df[['s_name', 'default_image']].iterrows()):
#       4     # print(url['default_image'], url['s_name'])
#       5     full_url = "https://www.starbucks.co.kr"  + url['default_image']
# ----> 6     urlretrieve(full_url, f'./starbucks/{url['s_name']}.jpg')
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:214, in urlretrieve(url, filename, reporthook, data)
#     197 """
#     198 Retrieve a URL into a temporary location on disk.
#     199
#    (...)    210 data file as well as the resulting HTTPMessage object.
#     211 """
#     212 url_type, path = _splittype(url)
# --> 214 with contextlib.closing(urlopen(url, data)) as fp:
#     215     headers = fp.info()
# ...
