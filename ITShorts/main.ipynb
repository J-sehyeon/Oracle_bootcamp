# %%
import requests
from bs4 import BeautifulSoup as BS

# %%
url = "https://yozm.wishket.com/magazine/detail/3866/"
res = BS(requests.get(url).text).find('div', id="article-detail-server")

# %%
res
# Out:
# <div class="w-full" id="article-detail-server"><!--$?--><template id="B:1"></template><!--/$--></div>
